# %%
numero1 = int(input("Introduce el primer número: "))
numero2 = int(input("Introduce el segundo número: "))

eleccion = 0

while eleccion != 7:
  print("""
  Indique la operación a realizar:
  1) Sumar
  2) Restar
  3) Multiplicar
  4) Dividir
  5) Potenciar
  6) Cambiar los números introducidos
  7) Salir de la calculadora
  """)
   
  eleccion = int(input())
  if eleccion == 1:
    print(" ")
    print("RESULTADO: ",numero1," + ",numero2," = ",numero1+numero2)
  elif eleccion == 2:
    print(" ")
    print("RESULTADO: ",numero1," - ",numero2," = ",numero1-numero2)
  elif eleccion == 3:
    print(" ")
    print("RESULTADO: ",numero1," x ",numero2," = ",numero1*numero2)
  elif eleccion == 4:
    print(" ")
    print("RESULTADO: ",numero1," / ",numero2," = ",float(numero1/numero2))
  elif eleccion == 5:
    print(" ")
    print("RESULTADO: ",numero1," ** ",numero2," = ",(numero1**numero2))
  elif eleccion == 6:
    numero1 = int(input("Introduzca el primer número: "))
    numero2 = int(input("Introduzca el segundo número: "))
  elif eleccion == 7:
    print ("Nos vemos pronto")
# Out:
# Introduce el primer número: 857
# Introduce el segundo número: 326
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 5
#
# RESULTADO:  857  **  326  =  ...
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 2
#
# RESULTADO:  857  -  326  =  531
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 3
#
# RESULTADO:  857  x  326  =  279382
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 6
# Introduzca el primer número: 94
# Introduzca el segundo número: 13
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 1
#
# RESULTADO:  94  +  13  =  107
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 4
#
# RESULTADO:  94  /  13  =  7.230769230769231
#
#   Indique la operación a realizar:
#   1) Sumar
#   2) Restar
#   3) Multiplicar
#   4) Dividir
#   5) Potenciar
#   6) Cambiar los números introducidos
#   7) Salir de la calculadora
#
# 7
# Nos vemos pronto
